# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from dython.nominal import associations
from dython.nominal import identify_nominal_columns

# %%
X = pd.read_csv('mes01_ano21.csv', delimiter=",", low_memory=False, keep_default_na=False)

# %%
X = X.drop(X.columns[0], axis=1)

# %%
X = X.drop(X.columns[0], axis=1)

# %%
X = X.drop(X.columns[0], axis=1)

# %%
X = X[['fever','cough','throat','dyspnoea','respdesc','diarrhoea','vomit', 'fatigue', 'lossm','losst']]

# %%
categorical_features=identify_nominal_columns(X)
categorical_features
# Out:
# ['fever',
#  'cough',
#  'throat',
#  'dyspnoea',
#  'respdesc',
#  'diarrhoea',
#  'vomit',
#  'fatigue',
#  'lossm',
#  'losst']

# %%
complete_correlation= associations(X, figsize=(8,8), annot=True, cmap='RdBu', cbar = False)
