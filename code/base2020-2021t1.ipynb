# %%
import pandas as pd
import numpy as np
import warnings
from difflib import get_close_matches
warnings.filterwarnings('ignore')

# %%
df20 = pd.read_csv('INFLUD20.csv', delimiter =';', low_memory=False, keep_default_na=False)

# %%
df21 = pd.read_csv('INFLUD21.csv', delimiter =';', low_memory=False, keep_default_na=False)

# %%
data20 = df20[ ['DT_NOTIFIC','SG_UF_NOT','FEBRE','TOSSE','GARGANTA','DISPNEIA','DESC_RESP','SATURACAO','DIARREIA','VOMITO',
                  'DOR_ABD','FADIGA','PERD_OLFT','PERD_PALA', 'CLASSI_FIN'] ]

# %%
data21 = df21[ ['DT_NOTIFIC','SG_UF_NOT','FEBRE','TOSSE','GARGANTA','DISPNEIA','DESC_RESP','SATURACAO','DIARREIA','VOMITO',
                  'DOR_ABD','FADIGA','PERD_OLFT','PERD_PALA', 'CLASSI_FIN'] ]

# %%
dfSP = data20['SG_UF_NOT']== 'AM'
df_SP20 = data20[dfSP]

# %%
df_SP20['DT_NOTIFIC'] = pd.to_datetime(df_SP20['DT_NOTIFIC'])
df_SP20_data = df_SP20.sort_values(by='DT_NOTIFIC')

# %%
df_SP20_data['year'] = df_SP20_data['DT_NOTIFIC'].dt.year
df_SP20_data['month'] = df_SP20_data['DT_NOTIFIC'].dt.month

# %%
df_SP20_data.drop(['DT_NOTIFIC'], axis=1, inplace=True)

# %%
df_SP20_data_final = df_SP20_data[['month','year','SG_UF_NOT','FEBRE','TOSSE','GARGANTA','DISPNEIA','DESC_RESP','SATURACAO','DIARREIA','VOMITO',
                  'DOR_ABD','FADIGA','PERD_OLFT','PERD_PALA', 'CLASSI_FIN']]

# %%
dfSP = data21['SG_UF_NOT']== 'AM'
df_SP21 = data21[dfSP]

# %%
df_SP21['DT_NOTIFIC'] = pd.to_datetime(df_SP21['DT_NOTIFIC'])
df_SP21_data = df_SP21.sort_values(by='DT_NOTIFIC')

# %%
df_SP21_data['year'] = df_SP21_data['DT_NOTIFIC'].dt.year
df_SP21_data['month'] = df_SP21_data['DT_NOTIFIC'].dt.month

# %%
df_SP21_data.drop(['DT_NOTIFIC'], axis=1, inplace=True)

# %%
df_SP21_data_final = df_SP21_data[['month','year','SG_UF_NOT','FEBRE','TOSSE','GARGANTA','DISPNEIA','DESC_RESP','SATURACAO','DIARREIA','VOMITO',
                  'DOR_ABD','FADIGA','PERD_OLFT','PERD_PALA','CLASSI_FIN']]

# %%
df_SP21_data_final
# Out:
#         month  year SG_UF_NOT FEBRE TOSSE GARGANTA DISPNEIA DESC_RESP  \
# 464096      1  2021        AM     1     1        1        1         1
# 529488      1  2021        AM     1              1
# 921272      1  2021        AM     1     1        1        1         1
# 706607      1  2021        AM     1                                 1
# 921270      1  2021        AM     1     1        1        1         1
# ...       ...   ...       ...   ...   ...      ...      ...       ...
# 217439     12  2022        AM     2     2        2        2         2
# 947281     12  2022        AM     1     1        2        1         2
# 583286     12  2022        AM     2     1        2        2         2
# 352631     12  2022        AM     1     1        1        1         1
# 311540     12  2022        AM     1     1        2        1         1
#
#        SATURACAO DIARREIA VOMITO DOR_ABD FADIGA PERD_OLFT PERD_PALA CLASSI_FIN
# 464096         1        2      2       1      1         1         1          5
# 529488                                                                       3
# 921272         1        2      2       2      2         2         2          5
# 706607         1        1      1                                             5
# 921270         1        2      2       2      1         1         1          5
# ...          ...      ...    ...     ...    ...       ...       ...        ...
# 217439         2        2      2       2      2         2         2          5
# 947281         1        2      2       2      2         2         2          5
# 583286         1        2      2       2      2         2         2          5
# 352631         1        2      1       2      2         2         2          5
# 311540         1        2      2       2      2         2         2          4
#
# [15321 rows x 16 columns]

# %%
SP20 = df_SP20_data_final

# %%
SP21 = df_SP21_data_final

# %%
SP20.drop(SP20.loc[SP20['year'] == 2019].index, inplace=True)

# %%
SP20.drop(SP20.loc[SP20['year'] == 2021].index, inplace=True)

# %%
SP20.drop(SP20.loc[SP20['year'] == 2022].index, inplace=True)

# %%
SP21.drop(SP21.loc[SP21['year'] == 2019].index, inplace=True)

# %%
SP21.drop(SP21.loc[SP21['year'] == 2020].index, inplace=True)

# %%
SP21.drop(SP21.loc[SP21['year'] == 2022].index, inplace=True)

# %%
SP20
# Out:
#          month  year SG_UF_NOT FEBRE TOSSE GARGANTA DISPNEIA DESC_RESP  \
# 9002         1  2020        AM     1     1        1        1         1
# 684981       1  2020        AM     1     1        1        1         1
# 949701       1  2020        AM     1     1        1        1         1
# 740432       1  2020        AM     1     1        2        2         2
# 328583       1  2020        AM     1     1        2        2         2
# ...        ...   ...       ...   ...   ...      ...      ...       ...
# 861691      12  2020        AM     2     1        2        1         1
# 534433      12  2020        AM     1     1        1        1         1
# 121714      12  2020        AM                             1
# 111269      12  2020        AM     1     1        1        1         1
# 1003619     12  2020        AM     1     2        2        1
#
#         SATURACAO DIARREIA VOMITO DOR_ABD FADIGA PERD_OLFT PERD_PALA  \
# 9002            1        2      2
# 684981          1        2      2
# 949701          1        2      2
# 740432          2        2      2
# 328583          2        2      2
# ...           ...      ...    ...     ...    ...       ...       ...
# 861691          1        2      2       2      1         2         2
# 534433          1        2      2       1      2         1         1
# 121714          1
# 111269          1        2      2       2      1
# 1003619         1        2      2       2      1
#
#         CLASSI_FIN
# 9002             4
# 684981           4
# 949701           5
# 740432           5
# 328583           4
# ...            ...
# 861691           3
# 534433           5
# 121714           4
# 111269           5
# 1003619          5
#
# [21161 rows x 16 columns]

# %%
SP20 = SP20.replace('9', 0)

# %%
SP20 = SP20.replace('', 2)

# %%
SP20
# Out:
#          month  year SG_UF_NOT FEBRE TOSSE GARGANTA DISPNEIA DESC_RESP  \
# 9002         1  2020        AM     1     1        1        1         1
# 684981       1  2020        AM     1     1        1        1         1
# 949701       1  2020        AM     1     1        1        1         1
# 740432       1  2020        AM     1     1        2        2         2
# 328583       1  2020        AM     1     1        2        2         2
# ...        ...   ...       ...   ...   ...      ...      ...       ...
# 861691      12  2020        AM     2     1        2        1         1
# 534433      12  2020        AM     1     1        1        1         1
# 121714      12  2020        AM     2     2        2        1         2
# 111269      12  2020        AM     1     1        1        1         1
# 1003619     12  2020        AM     1     2        2        1         2
#
#         SATURACAO DIARREIA VOMITO DOR_ABD FADIGA PERD_OLFT PERD_PALA  \
# 9002            1        2      2       2      2         2         2
# 684981          1        2      2       2      2         2         2
# 949701          1        2      2       2      2         2         2
# 740432          2        2      2       2      2         2         2
# 328583          2        2      2       2      2         2         2
# ...           ...      ...    ...     ...    ...       ...       ...
# 861691          1        2      2       2      1         2         2
# 534433          1        2      2       1      2         1         1
# 121714          1        2      2       2      2         2         2
# 111269          1        2      2       2      1         2         2
# 1003619         1        2      2       2      1         2         2
#
#         CLASSI_FIN
# 9002             4
# 684981           4
# 949701           5
# 740432           5
# 328583           4
# ...            ...
# 861691           3
# 534433           5
# 121714           4
# 111269           5
# 1003619          5
#
# [21161 rows x 16 columns]

# %%
SP21 = SP21.replace('9', 0)

# %%
SP21 = SP21.replace('', 2)

# %%
SP21
# Out:
#         month  year SG_UF_NOT FEBRE TOSSE GARGANTA DISPNEIA DESC_RESP  \
# 464096      1  2021        AM     1     1        1        1         1
# 529488      1  2021        AM     1     2        1        2         2
# 921272      1  2021        AM     1     1        1        1         1
# 706607      1  2021        AM     1     2        2        2         1
# 921270      1  2021        AM     1     1        1        1         1
# ...       ...   ...       ...   ...   ...      ...      ...       ...
# 719929     12  2021        AM     1     1        1        2         1
# 161360     12  2021        AM     1     1        2        1         1
# 483503     12  2021        AM     1     1        2        1         1
# 516406     12  2021        AM     2     2        2        1         1
# 120878     12  2021        AM     1     1        2        1         2
#
#        SATURACAO DIARREIA VOMITO DOR_ABD FADIGA PERD_OLFT PERD_PALA CLASSI_FIN
# 464096         1        2      2       1      1         1         1          5
# 529488         2        2      2       2      2         2         2          3
# 921272         1        2      2       2      2         2         2          5
# 706607         1        1      1       2      2         2         2          5
# 921270         1        2      2       2      1         1         1          5
# ...          ...      ...    ...     ...    ...       ...       ...        ...
# 719929         2        2      2       2      2         2         2          4
# 161360         1        2      2       2      1         2         2          2
# 483503         1        2      2       2      2         2         2          4
# 516406         1        2      2       2      1         2         2          5
# 120878         2        2      2       2      2         2         2          4
#
# [15107 rows x 16 columns]

# %%
SP20.drop(SP20.loc[SP20['CLASSI_FIN'] == '0'].index, inplace=True)

# %%
SP20.drop(SP20.loc[SP20['CLASSI_FIN'] == '2'].index, inplace=True)

# %%
SP20.drop(SP20.loc[SP20['CLASSI_FIN'] == 2].index, inplace=True)

# %%
SP20.drop(SP20.loc[SP20['CLASSI_FIN'] == '3'].index, inplace=True)

# %%
SP20.drop(SP20.loc[SP20['CLASSI_FIN'] == '1'].index, inplace=True)

# %%
SP20.drop(SP20.loc[SP20['CLASSI_FIN'] == ''].index, inplace=True)

# %%
SP21.drop(SP21.loc[SP21['CLASSI_FIN'] == '0'].index, inplace=True)

# %%
SP21.drop(SP21.loc[SP21['CLASSI_FIN'] == '2'].index, inplace=True)

# %%
SP21.drop(SP21.loc[SP21['CLASSI_FIN'] == 2].index, inplace=True)

# %%
SP21.drop(SP21.loc[SP21['CLASSI_FIN'] == '3'].index, inplace=True)

# %%
SP21.drop(SP21.loc[SP21['CLASSI_FIN'] == '1'].index, inplace=True)

# %%
SP21.drop(SP21.loc[SP21['CLASSI_FIN'] == ''].index, inplace=True)

# %%
SP20['CLASSI_FIN'] = SP20['CLASSI_FIN'].replace('5', 1)

# %%
SP20['CLASSI_FIN'] = SP20['CLASSI_FIN'].replace('4', 0)

# %%
SP21['CLASSI_FIN'] = SP21['CLASSI_FIN'].replace('5', 1)

# %%
SP21['CLASSI_FIN'] = SP21['CLASSI_FIN'].replace('4', 0)
